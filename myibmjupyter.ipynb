# %%
i=0

# %% [markdown]
# Infinite Loop

# %%
while(True):
    i+=1
    print("You have circumnavigated Jupyter",i,"times.")
# Out:
# You have circumnavigated Jupyter 1 times.
# You have circumnavigated Jupyter 2 times.
# You have circumnavigated Jupyter 3 times.
# You have circumnavigated Jupyter 4 times.
# You have circumnavigated Jupyter 5 times.
# You have circumnavigated Jupyter 6 times.
# You have circumnavigated Jupyter 7 times.
# You have circumnavigated Jupyter 8 times.
# You have circumnavigated Jupyter 9 times.
# You have circumnavigated Jupyter 10 times.
# You have circumnavigated Jupyter 11 times.
# You have circumnavigated Jupyter 12 times.
# You have circumnavigated Jupyter 13 times.
# You have circumnavigated Jupyter 14 times.
# You have circumnavigated Jupyter 15 times.
# You have circumnavigated Jupyter 16 times.
# You have circumnavigated Jupyter 17 times.
# You have circumnavigated Jupyter 18 times.
# You have circumnavigated Jupyter 19 times.
# You have circumnavigated Jupyter 20 times.
# You have circumnavigated Jupyter 21 times.
# You have circumnavigated Jupyter 22 times.
# ...
